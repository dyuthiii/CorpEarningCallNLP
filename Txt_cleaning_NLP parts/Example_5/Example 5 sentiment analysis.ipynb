# %%
from clean_senti_fns import *
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/QMSS_class/NLP/project_earning_calls/final proj Cleaning, NLP/Example_5/Example_5_text.csv")
data.head()
# Out:
#          Topic                                               Text
# 0  5.1 topic 0  fter increase year net u pet population increa...
# 1  5.2 topic 1  let update capital deployment continue success...
# 2  5.3 topic 2  gross profit margin second quarter adjust oper...
# 3  5.4 topic 3  yeah hi thank color hope tell u expect medicai...
# 4  5.5 topic 4  believe healthcare deliver low cost low acuity...

# %% [markdown]
# Tokenizing into sentences

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#nltk.download('wordnet')
# Import the lexicon
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Create an instance of SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()
data['vader'] = data['Text'].apply(lambda x: vader.polarity_scores(x)['compound'])
write_pickle(data, "/content/drive/MyDrive/QMSS_class/NLP/project_earning_calls/final proj Cleaning, NLP/Example_5/", "Eg5_vader")

# %%
#Analyze sentiment
data['sentiment'] = data['Text'].apply(analyze_sentiment)
data.head()
# Out:
#          Topic                                               Text   vader  \
# 0  5.1 topic 0  fter increase year net u pet population increa...  0.9349
# 1  5.2 topic 1  let update capital deployment continue success...  0.9493
# 2  5.3 topic 2  gross profit margin second quarter adjust oper...  0.9682
# 3  5.4 topic 3  yeah hi thank color hope tell u expect medicai...  0.9652
# 4  5.5 topic 4  believe healthcare deliver low cost low acuity...  0.8316
#
#                                            sentiment
# 0  {'neg': 0.031, 'neu': 0.779, 'pos': 0.19, 'com...
# 1  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'comp...
# 2  {'neg': 0.063, 'neu': 0.665, 'pos': 0.272, 'co...
# 3  {'neg': 0.019, 'neu': 0.618, 'pos': 0.363, 'co...
# 4  {'neg': 0.084, 'neu': 0.716, 'pos': 0.2, 'comp...

# %%
write_pickle(data, "/content/drive/MyDrive/QMSS_class/NLP/project_earning_calls/final proj Cleaning, NLP/Example_5/", "Eg5_sentiment_score")

# %%
data.head(10)
# Out:
#          Topic                                               Text   vader  \
# 0  5.1 topic 0  fter increase year net u pet population increa...  0.9349
# 1  5.2 topic 1  let update capital deployment continue success...  0.9493
# 2  5.3 topic 2  gross profit margin second quarter adjust oper...  0.9682
# 3  5.4 topic 3  yeah hi thank color hope tell u expect medicai...  0.9652
# 4  5.5 topic 4  believe healthcare deliver low cost low acuity...  0.8316
# 5  5.6 topic 5  think dynamic play refer patient identificatio...  0.9393
# 6  5.7 topic 6  sure firstly mean china come ahead expectation...  0.8519
# 7  5.8 topic 7  innovation leader idexx growth continue outpac...  0.9884
#
#                                            sentiment
# 0  {'neg': 0.031, 'neu': 0.779, 'pos': 0.19, 'com...
# 1  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'comp...
# 2  {'neg': 0.063, 'neu': 0.665, 'pos': 0.272, 'co...
# 3  {'neg': 0.019, 'neu': 0.618, 'pos': 0.363, 'co...
# ...

# %%
import csv

# %%
csv_file_path = "/content/drive/MyDrive/QMSS_class/NLP/project_earning_calls/final proj Cleaning, NLP/Example_5/Eg5_sentiment_score.csv"

# %%
data.to_csv(csv_file_path, index=False)
